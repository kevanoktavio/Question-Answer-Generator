# %%
# importing dependencies
import requests # for http request
from bs4 import BeautifulSoup # for web scraping
import re # for regex
import unicodedata # for standardising text
import pandas as pd # for data manipulation
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM # for our NLP pre-trained model

# %% [markdown]
# # Why Google's Flan-T5
#
# In this project, I am using Google's Flan-T5 'base' version. Flan stand for Fine-tuned LAnguage Net while T5 stands for Text-to-Text Transfer Transformer.
#
# Flan-T5 is a pre-trained NLP model that was trained for a variety of language tasks such as translation, summarisation and question answering (QA). Since QA is a task it was trained on, Flan-T5 is appropriate for this task as that's half of the battle done! Many of the tasks used to train Flan-T5 also heavily involve questions such as logical reasoning and verifying scientific facts. Hence, the transfer learning is effective to something as general as generating questions.
#
# I used the base version as it's the standard version and this small-scale task does not benefit from using the Large nor XXL version.

# %%
def generate_qa_pairs(url):
    wiki_extract = get_wiki_extract(url) # web scrape and clean the wikipedia page
    
    tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-base") # here we use google's flan-t5-base model
    model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-base")
    
    qa_pairs = []
    for text in wiki_extract: # go through every paragraph of the page
        # generate question for the current text
        question = generate_question(text, tokenizer, model)
        
        # extract answer for the question using the same tokenizer and model
        answer = extract_answer(text, question, tokenizer, model)
        
        # store the question-answer pairs in a list of dictionaries
        qa_pairs.append({"question": question, "answer": answer})
    
    return qa_pairs

# helpter functions for web scraping
def get_wiki_extract(url):
    soup = get_soup(url) # get request to the wikipedia page
    headers = ['h1', 'h2', 'h3', 'h4', 'h5', 'h6'] # relevant texts are enclosed within these 6 headers
    wiki_extract = []
    for tag in soup.find_all(): # we first break the text everytime it's a new section
        if tag.name in headers and tag.text != 'Contents': # ignore unnecessary elements (tables, UI elements, etc.) and wikipedia's contents box
            p = '' # we find all paragraphs after each header
            for ne in tag.next_elements: # loop through the next elements after each header
                if ne.name == 'p': # the texts are always enclosed in <p>
                    p += get_paragraph_text(ne) # extract the text
                if ne.name in headers: # stop once we find the next header
                    break
            if p: # ignore empty sections
                wiki_extract.append(clean_wiki_content(p))
    
    separated_wiki_extract = [] # split the texts further by paragraphs
    for item in wiki_extract:
        if '\n' in item: # check for breaking space then split by those
            items = item.split('\n')
            separated_wiki_extract.extend(filter(None, items)) # filter out empty strings
        else: # otherwise keep it as it is
            separated_wiki_extract.append(item)
    
    return separated_wiki_extract

def get_soup(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.content , 'html.parser') # parse html content
    return soup

def get_paragraph_text(p):
    paragraph_text = ''
    for tag in p.children: # get all the texts inside the paragraph
        if tag.name == "style" or tag.text.isspace(): # wikipedia sometimes put style tag or empty texts in a <p> (must have been on a tight deadline). We don't want none of those!
            continue
        paragraph_text += tag.text # by only taking the text, we ignore the various HMTL tags suchs as <i>, <b>, <a href>, etc.
    return paragraph_text

def clean_wiki_content(text): # most of the text pre-processing is here
    text = re.sub(r"\[\d+\]|\[[a-zA-Z]\]", "", text) # remove citations
    text = text.replace("[edit]", "") # wikipedia thinks we are smart enough to contribute. have to remove these edit buttons!
    text = unicodedata.normalize("NFKD", text) # standardise the non-breaking spaces and others
    return text

# helper functions for using flan-t5
def generate_question(text, tokenizer, model):
    input_text = "generate question: " + text # this is the input we are going to plug into the model
    input_text = input_text[:512] # 512 is the character limit of this model
    input_ids = tokenizer.encode(input_text, return_tensors="pt") #tokenize first
    outputs = model.generate(input_ids, max_new_tokens = 512)
    question = tokenizer.batch_decode(outputs, skip_special_tokens=True)[0] # decode and return away!
    return question

def extract_answer(text, question, tokenizer, model): # the same exact flow as the question generation part
    input_text = question + " context: " + text # just different prompt
    input_text = input_text[:512] # again, 512 is the character limit of this model
    input_ids = tokenizer.encode(input_text, return_tensors="pt")
    outputs = model.generate(input_ids, max_new_tokens = 512)
    answer = tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]
    return answer

# %% [markdown]
# # Calling the function

# %%
url = "https://en.m.wikipedia.org/wiki/The_Elder_Scrolls_V:_Skyrim"
qa_pairs_skyrim = generate_qa_pairs(url)
qa_pairs_skyrim
# Out:
# [{'question': 'What is the name of the game that was released worldwide for Microsoft Windows, PlayStation 3, and Xbox 360?',
#   'answer': 'The Elder Scrolls V: Skyrim'},
#  {'question': 'What is the name of the northernmost province of Tamriel?',
#   'answer': 'Skyrim'},
#  {'question': 'What is the name of the game that Skyrim was developed using?',
#   'answer': 'Oblivion'},
#  {'question': 'What was the name of the game that was released in June 2013?',
#   'answer': 'The Elder Scrolls V: Skyrim – Legendary Edition'},
#  {'question': 'What is the name of the game that is played from a first- or third-person perspective?',
#   'answer': 'The Elder Scrolls V: Skyrim'},
#  {'question': 'What is the primary attribute of a character?',
#   'answer': 'health'},
#  {'question': 'What is the name of the first game in the series?',
#   'answer': 'The Elder Scrolls IV: Oblivion'},
#  {'question': 'What is the name of the province that the Empire has recently fought a war with?',
#   'answer': 'Skyrim'},
#  {'question': 'Who is the jarl of Windhelm?', 'answer': 'Ulfric Stormcloak'},
#  {'question': 'Who was the last dragon?', 'answer': 'Paarthurnax'},
#  {'question': 'How many races can the player character be from?',
#   'answer': 'ten'},
#  {'question': 'Who is the primary antagonist of Skyrim?', 'answer': 'Alduin'},
#  {'question': 'Who is the player who was caught up in the skirmish and mistakenly believed to be a rebel?',
#   'answer': 'Ulfric Stormcloak'},
#  {'question': "Who is Delphine's daughter?", 'answer': 'Alduin'},
#  {'question': 'What is the name of the shout that Arngeir does not know?',
#   'answer': 'Dragonrend'},
#  {'question': 'Who is the captured dragon?', 'answer': 'Whiterun'},
#  {'question': 'What was the name of the game Bethesda Game Studios began work on in 2006?',
#   'answer': 'Oblivion'},
#  {'question': 'What is the name of the game world that the team set the game in?',
#   'answer': 'Skyrim'},
#  {'question': 'What was the codebase for Skyrim?', 'answer': 'Fallout 3'},
#  {'question': 'What is the name of the game that Skyrim was released on?',
#   'answer': 'Elder Scrolls'},
#  {'question': 'Skyrim, what was the name of the game that Howard presented the announcement trailer for?',
#   'answer': 'Skyrim'},
#  {'question': 'What is the name of the game that was released on October 28, 2016?',
#   'answer': 'The Elder Scrolls V: Skyrim – Special Edition'},
#  {'question': 'What year did Skyrim first appear on the Nintendo Switch?',
#   'answer': '2016'},
#  {'question': 'What is the name of the game that was released in November 2021?',
#   'answer': 'The Elder Scrolls V: Skyrim – Anniversary Edition'},
#  {'question': 'What is the name of the game that was being ported to next-generation systems?',
#   'answer': 'Skyrim'},
#  {'question': 'What is the name of the first downloadable add-on for Skyrim?',
#   'answer': 'Dawnguard'},
#  {'question': 'What is the name of the mod that Skyrim uses to make the game more stable?',
#   'answer': 'Creation Kit'},
#  {'question': "What was the game's name?", 'answer': 'The Elder Scrolls'},
#  {'question': 'What is the name of the game that was released in the year Skyrim was released?',
#   'answer': 'PlayStation 3'},
#  {'question': 'How many more physical copies were sold than PS3?',
#   'answer': '1.3 million'},
#  {'question': 'What award did Skyrim receive from various gaming sites and publications?',
#   'answer': 'PC Game of the Year'},
#  {'question': 'What is the name of the game that Skyrim has been credited with influencing?',
#   'answer': 'The Legend of Zelda: Breath of the Wild'}]

# %% [markdown]
# # Evaluating the results
#
# RELEVANCE
#
# From the example of Skyrim above, we can see that the question-pairs are pretty good and produces both general ("What is the name of the game world that the team set the game in?") and detailed ("What is the name of the game that Skyrim has been credited with influencing?") questions
#
# However,the question can be too general sometimes. There are questions like:
# - "What is the name of the game that was released worldwide for Microsoft Windows, PlayStation 3, and Xbox 360?"
# - "What is the name of the game that was released in June 2013?"
# The model produces questions like this because it processes the texts by themseleves, in isolation from the other paragraphs and also the broader general knowledge.
#
# CORRECTNESS
#
# Generally the answers are correct as long as the correct answer is found nearby. Otherwise, the model seems to confuse nearby proper nouns as the answer. For example:
#
# Question: "Who is the captured dragon?"
#
# Context: "The Dragonborn's allies hatch a plan to capture a dragon at Whiterun. The Dragonborn helps negotiate a truce in the civil war to prevent either side from capturing Whiterun during this delicate operation. The captured dragon, Odahviing, questions whether Alduin deserves lordship over dragons."
#
# Since the ground truth, "Odahviing", is found 2 sentences away from the mention of the captured dragon, the model assigns higher probability to "Whiterun", a location, instead.
#
# IMPROVEMENTS
#
# The most immediate improvement to this model is to add the ability to take into account the whole wikipedia page as input at once before generating questions. This will encourage the model to generate more relevant questions instead of looking at each paragraph in isolation. Currently, the limit is at 512 characters and expanding it would require much more computational power.

# %% [markdown]
# # Convert to DataFrame for csv conversion

# %%
df_skyrim = pd.DataFrame(qa_pairs_skyrim)
df_skyrim
# Out:
#                                              question  \
# 0   What is the name of the game that was released...
# 1   What is the name of the northernmost province ...
# 2   What is the name of the game that Skyrim was d...
# 3   What was the name of the game that was release...
# 4   What is the name of the game that is played fr...
# 5       What is the primary attribute of a character?
# 6   What is the name of the first game in the series?
# 7   What is the name of the province that the Empi...
# 8                        Who is the jarl of Windhelm?
# 9                            Who was the last dragon?
# 10   How many races can the player character be from?
# 11           Who is the primary antagonist of Skyrim?
# 12  Who is the player who was caught up in the ski...
# 13                        Who is Delphine's daughter?
# 14  What is the name of the shout that Arngeir doe...
# 15                        Who is the captured dragon?
# 16  What was the name of the game Bethesda Game St...
# 17  What is the name of the game world that the te...
# 18                  What was the codebase for Skyrim?
# 19  What is the name of the game that Skyrim was r...
# 20  Skyrim, what was the name of the game that How...
# 21  What is the name of the game that was released...
# 22  What year did Skyrim first appear on the Ninte...
# 23  What is the name of the game that was released...
# 24  What is the name of the game that was being po...
# 25  What is the name of the first downloadable add...
# 26  What is the name of the mod that Skyrim uses t...
# 27                          What was the game's name?
# 28  What is the name of the game that was released...
# 29  How many more physical copies were sold than PS3?
# 30  What award did Skyrim receive from various gam...
# 31  What is the name of the game that Skyrim has b...
#
#                                                answer
# 0                         The Elder Scrolls V: Skyrim
# 1                                              Skyrim
# 2                                            Oblivion
# 3     The Elder Scrolls V: Skyrim – Legendary Edition
# 4                         The Elder Scrolls V: Skyrim
# 5                                              health
# 6                      The Elder Scrolls IV: Oblivion
# 7                                              Skyrim
# 8                                   Ulfric Stormcloak
# 9                                         Paarthurnax
# 10                                                ten
# 11                                             Alduin
# 12                                  Ulfric Stormcloak
# 13                                             Alduin
# 14                                         Dragonrend
# 15                                           Whiterun
# 16                                           Oblivion
# 17                                             Skyrim
# 18                                          Fallout 3
# 19                                      Elder Scrolls
# 20                                             Skyrim
# 21      The Elder Scrolls V: Skyrim – Special Edition
# 22                                               2016
# 23  The Elder Scrolls V: Skyrim – Anniversary Edition
# 24                                             Skyrim
# 25                                          Dawnguard
# 26                                       Creation Kit
# 27                                  The Elder Scrolls
# 28                                      PlayStation 3
# 29                                        1.3 million
# 30                                PC Game of the Year
# 31            The Legend of Zelda: Breath of the Wild

# %%
df_skyrim.to_csv('qa_pairs_skyrim.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# # Additional results

# %%
url = "https://en.wikipedia.org/wiki/Singapore"
qa_pairs_sg = generate_qa_pairs(url)
qa_pairs_sg
# Out:
# [{'question': 'What is the largest island in Southeast Asia?',
#   'answer': 'Johor'},
#  {'question': 'What was the name of the British Empire that Singapore came under the direct control of?',
#   'answer': 'British Empire'},
#  {'question': 'What is the main idea of the passage?',
#   'answer': 'globalisation'},
#  {'question': 'What is the name of the country that has a Westminster system of unicameral parliamentary government?',
#   'answer': 'Singapore'},
#  {'question': 'What is the Malay name for the country?',
#   'answer': 'Singapura'},
#  {'question': 'What was the name of the Kingdom of Singapura?',
#   'answer': 'Temasek'},
#  {'question': 'Singapore when he arrived in what country?',
#   'answer': 'Singapore'},
#  {'question': 'Which happened first, the Battle of Singapore or the surrender of the British forces?',
#   'answer': 'Battle of Singapore'},
#  {'question': 'What happened first, the surrender of Japanese forces in the region or the surrender of General Seishir Itagaki?',
#   'answer': 'surrender of Japanese forces in the region'},
#  {'question': 'What was the name of the ruling party of Malaya?',
#   'answer': 'U'},
#  {'question': 'ASEAN', 'answer': 'ASEAN.'},
#  {'question': 'What is the name of the person who is appointed by the Prime Minister?',
#   'answer': 'President'},
#  {'question': 'Who is the president of the United States?',
#   'answer': 'presidential elections'},
#  {'question': 'What is the term for a racial community that has not been elected to the presidency in the five most recent terms?',
#   'answer': 'reserved'},
#  {'question': 'Which group represents the majority of the Parliament?',
#   'answer': 'nonpartisan'},
#  {'question': "What is Singapore's stated foreign policy priority?",
#   'answer': 'maintaining security in Southeast Asia and surrounding territories'},
#  {'question': "What is the name of the military that is seen as the guarantor of the country's independence?",
#   'answer': 'The Singaporean military'},
#  {'question': "What is the country's capital punishment?",
#   'answer': 'death penalty'},
#  {'question': 'What is the name of the country that has a highly developed market economy?',
#   'answer': 'Singapore'},
#  {'question': "What is Singapore's economy like?", 'answer': 'competitive'},
#  {'question': 'What is the lowest unemployment rate in Singapore?',
#   'answer': '4%'},
#  {'question': 'What is the largest island in Singapore?',
#   'answer': 'Pulau Ujong'},
#  {'question': 'How many years has Singapore been a "garden city"?',
#   'answer': '17'},
#  {'question': 'What time of day does Singapore follow?', 'answer': 'rainfall'},
#  {'question': 'What is the main reason Singapore considers water a national security issue?',
#   'answer': 'water access is universal and of high quality'},
#  {'question': 'What was the first congestion pricing scheme implemented in Singapore?',
#   'answer': 'The Singapore Area Licensing Scheme'},
#  {'question': 'What is the name of the airport that Singapore Changi Airport hosts a network of over 100 airlines connecting Singapore to some 300 cities in about 70 countries and territories worldwide?',
#   'answer': 'Singapore Changi Airport'},
#  {'question': "Which airport in Doha has been rated as the world's best airport?",
#   'answer': 'Hamad International Airport'},
#  {'question': 'What is the largest port in the world?', 'answer': 'Shanghai'},
#  {'question': 'What is the largest export of Singapore?',
#   'answer': 'refined petroleum'},
#  {'question': 'What is the largest industry in Singapore?',
#   'answer': 'Tourism'},
#  {'question': 'Which group of people are not citizens?',
#   'answer': 'foreign workers'},
#  {'question': 'What religion is the most widely practised religion in Singapore?',
#   'answer': 'Buddhist'},
#  {'question': 'What is the official language of Singapore?',
#   'answer': 'English language'},
#  {'question': 'English is the language of instruction in all public schools, and all subjects are taught and examined in English except for the "mother tongue" language paper.',
#   'answer': 'context: Education for primary, secondary, and tertiary levels is mostly supported by the state. All institutions, public and private, must be registered with the Ministry of Education (MOE).'},
#  {'question': 'What is the highest life expectancy in Singapore?',
#   'answer': '84.8 years'},
#  {'question': 'What is the traditional description of Singapore?',
#   'answer': 'a nation'},
#  {'question': 'What is the name of the Singapore Art Museum?',
#   'answer': 'The National Gallery Singapore'},
#  {'question': 'What is the name of the country that is considered to be a place of cultural diffusion?',
#   'answer': 'Singapore'},
#  {'question': 'What sport was the first Olympic medalist in Singapore?',
#   'answer': 'Weightlifter Tan Howe Liang'},
#  {'question': 'What is the name of the company that controls most of the domestic media in Singapore?',
#   'answer': 'SPH Media Trust'},
#  {'question': "What is the equator's radial velocity?", 'answer': '1.367'}]

# %%
df_sg = pd.DataFrame(qa_pairs_sg)
df_sg
# Out:
#                                              question  \
# 0       What is the largest island in Southeast Asia?
# 1   What was the name of the British Empire that S...
# 2               What is the main idea of the passage?
# 3   What is the name of the country that has a Wes...
# 4             What is the Malay name for the country?
# 5      What was the name of the Kingdom of Singapura?
# 6          Singapore when he arrived in what country?
# 7   Which happened first, the Battle of Singapore ...
# 8   What happened first, the surrender of Japanese...
# 9    What was the name of the ruling party of Malaya?
# 10                                              ASEAN
# 11  What is the name of the person who is appointe...
# 12         Who is the president of the United States?
# 13  What is the term for a racial community that h...
# 14  Which group represents the majority of the Par...
# 15  What is Singapore's stated foreign policy prio...
# 16  What is the name of the military that is seen ...
# 17          What is the country's capital punishment?
# 18  What is the name of the country that has a hig...
# 19                  What is Singapore's economy like?
# 20  What is the lowest unemployment rate in Singap...
# 21           What is the largest island in Singapore?
# 22  How many years has Singapore been a "garden ci...
# 23            What time of day does Singapore follow?
# 24  What is the main reason Singapore considers wa...
# 25  What was the first congestion pricing scheme i...
# 26  What is the name of the airport that Singapore...
# 27  Which airport in Doha has been rated as the wo...
# 28             What is the largest port in the world?
# 29           What is the largest export of Singapore?
# 30         What is the largest industry in Singapore?
# 31            Which group of people are not citizens?
# 32  What religion is the most widely practised rel...
# 33        What is the official language of Singapore?
# 34  English is the language of instruction in all ...
# 35  What is the highest life expectancy in Singapore?
# 36  What is the traditional description of Singapore?
# 37      What is the name of the Singapore Art Museum?
# 38  What is the name of the country that is consid...
# 39  What sport was the first Olympic medalist in S...
# 40  What is the name of the company that controls ...
# 41             What is the equator's radial velocity?
#
#                                                answer
# 0                                               Johor
# 1                                      British Empire
# 2                                       globalisation
# 3                                           Singapore
# 4                                           Singapura
# 5                                             Temasek
# 6                                           Singapore
# 7                                 Battle of Singapore
# 8          surrender of Japanese forces in the region
# 9                                                   U
# 10                                             ASEAN.
# 11                                          President
# 12                             presidential elections
# 13                                           reserved
# 14                                        nonpartisan
# 15  maintaining security in Southeast Asia and sur...
# 16                           The Singaporean military
# 17                                      death penalty
# 18                                          Singapore
# 19                                        competitive
# 20                                                 4%
# 21                                        Pulau Ujong
# 22                                                 17
# 23                                           rainfall
# 24      water access is universal and of high quality
# 25                The Singapore Area Licensing Scheme
# 26                           Singapore Changi Airport
# 27                        Hamad International Airport
# 28                                           Shanghai
# 29                                  refined petroleum
# 30                                            Tourism
# 31                                    foreign workers
# 32                                           Buddhist
# 33                                   English language
# 34  context: Education for primary, secondary, and...
# 35                                         84.8 years
# 36                                           a nation
# 37                     The National Gallery Singapore
# 38                                          Singapore
# 39                        Weightlifter Tan Howe Liang
# 40                                    SPH Media Trust
# 41                                              1.367

# %%
df_sg.to_csv('qa_pairs_sg.csv', index=False, encoding='utf-8-sig')
